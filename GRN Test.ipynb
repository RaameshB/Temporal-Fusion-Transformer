# %%
import nn as tft_nn
import torch

# %%
grn = tft_nn.GRN(4, 10, 2)

# %%
a = torch.rand((8, 48, 4))
c = torch.rand((8, 48, 2))

# %%
grn(a, c)
# Out:
# tensor([[[-0.5039, -0.4245, -0.7877,  1.7160],
#          [-0.3945, -1.4314,  1.1653,  0.6606],
#          [ 0.7767, -0.0959, -1.5965,  0.9156],
#          ...,
#          [ 0.0327,  0.0558,  1.3685, -1.4569],
#          [ 0.1037,  0.6892, -1.6613,  0.8684],
#          [ 1.4123, -1.0984,  0.4548, -0.7686]],
#
#         [[ 0.1626,  0.9125, -1.6695,  0.5944],
#          [ 1.3306, -1.3844, -0.3671,  0.4209],
#          [-1.2777,  1.5225, -0.0377, -0.2070],
#          ...,
#          [ 0.9414, -0.5721, -1.3503,  0.9810],
#          [ 1.2065,  0.6979, -0.6031, -1.3012],
#          [ 1.0780,  0.7107, -0.2890, -1.4997]],
#
#         [[ 1.4890, -0.8985,  0.3375, -0.9281],
#          [ 0.7603,  0.5047, -1.7203,  0.4554],
#          [ 0.7133, -0.6023, -1.3049,  1.1938],
#          ...,
#          [ 0.1250,  0.4093, -1.6225,  1.0881],
#          [ 1.4835,  0.2834, -1.1637, -0.6031],
#          [ 1.5219, -0.8227, -0.9668,  0.2676]],
#
#         ...,
#
# ...
